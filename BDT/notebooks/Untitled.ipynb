# %%
# %pylab inline
import uproot
import mplhep as hep
import pandas as pd
plt.style.use(hep.styles.CMS)
import sys
sys.path.append("/home/users/bsathian/HHggTauTau/prototype_looper/BDT/helpers/")
import utils
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_pickle("../20211217_data_driven_zipped.pkl")

df["target"] = np.zeros(len(df))
df.loc[df["process_id"] < 0, "target"] = 1
df = df.loc[(df["process_id"] != -2) & (df["process_id"]) >= -4]
df = df.loc[df["process_id"] != 0]

# %%
selection_string = ((df["process_id"] < 0) | (df["process_id"] >= 9)) & (df["train_label"] == 1)
results = utils.calc_roc_and_unc(df.loc[selection_string, "target"], df.loc[selection_string, "bdt_data_driven"], df.loc[selection_string, "weight"])

plot(results["fpr"], results["tpr"], label="AUC = {:0.3f}".format(results["auc"]))
plt.grid()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Test ROC signal vs resonant backgrounds")
plt.legend()
plt.savefig("data_driven_auc_v_resonant.pdf")
# Out:
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.

# %%
selection_string = (df["process_id"] < 8) & (df["train_label"] == 1)
results = utils.calc_roc_and_unc(df.loc[selection_string, "target"], df.loc[selection_string, "bdt_data_driven"], df.loc[selection_string, "weight"])

plot(results["fpr"], results["tpr"], label="AUC = {:0.3f}".format(results["auc"]))
plt.grid()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Test ROC signal vs Nonresonant, no GJets")
plt.legend()
plt.savefig("data_driven_auc_v_nonresonant_no_gjets.pdf")

print(results["auc"])
# Out:
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 0.9687916172043075

# %%
selection_string = (df["process_id"] < 9) & (df["train_label"] == 1)
results = utils.calc_roc_and_unc(df.loc[selection_string, "target"], df.loc[selection_string, "bdt_data_driven"], df.loc[selection_string, "weight"])

plot(results["fpr"], results["tpr"], label="AUC = {:0.3f}".format(results["auc"]))
plt.grid()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Test ROC signal vs Nonresonant")
plt.legend()
plt.savefig("data_driven_auc_v_nonresonant.pdf")

print(results["auc"])
# Out:
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 0.9893288399509035

# %%
selection_string = ((df["process_id"] < 0) | (df["process_id"] == 8)) & (df["train_label"] == 1)
results = utils.calc_roc_and_unc(df.loc[selection_string, "target"], df.loc[selection_string, "bdt_data_driven"], df.loc[selection_string, "weight"])

plot(results["fpr"], results["tpr"], label="AUC = {:0.3f}".format(results["auc"]))
plt.grid()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Test ROC signal vs GJets")
plt.legend()
plt.savefig("data_driven_only_auc_v_gjets.pdf")
# Out:
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.

# %%
df = pd.read_pickle("../20211217_mc_only_zipped.pkl")

df["target"] = np.zeros(len(df))
df.loc[df["process_id"] < 0, "target"] = 1
df = df.loc[(df["process_id"] != -2) & (df["process_id"]) >= -4]
df = df.loc[df["process_id"] != 0]

# %%
selection_string = ((df["process_id"] < 0) | (df["process_id"] >= 9)) & (df["train_label"] == 1)
results = utils.calc_roc_and_unc(df.loc[selection_string, "target"], df.loc[selection_string, "bdt_mc_only"], df.loc[selection_string, "weight"])

plot(results["fpr"], results["tpr"], label="AUC = {:0.3f}".format(results["auc"]))
plt.grid()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Test ROC signal vs resonant backgrounds")
plt.legend()
plt.savefig("mc_only_auc_v_resonant.pdf")
# Out:
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.

# %%
selection_string = (df["process_id"] < 8) & (df["train_label"] == 1)
results = utils.calc_roc_and_unc(df.loc[selection_string, "target"], df.loc[selection_string, "bdt_mc_only"], df.loc[selection_string, "weight"])

plot(results["fpr"], results["tpr"], label="AUC = {:0.3f}".format(results["auc"]))
plt.grid()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Test ROC signal vs Nonresonant, no GJets")
plt.legend()
plt.savefig("mc_only_auc_v_nonresonant_no_gjets.pdf")

print(results["auc"])
# Out:
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 0.9665190415728734

# %%
selection_string = (df["process_id"] < 9) & (df["train_label"] == 1)
results = utils.calc_roc_and_unc(df.loc[selection_string, "target"], df.loc[selection_string, "bdt_mc_only"], df.loc[selection_string, "weight"])

plot(results["fpr"], results["tpr"], label="AUC = {:0.3f}".format(results["auc"]))
plt.grid()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Test ROC signal vs Nonresonant")
plt.legend()
plt.savefig("mc_only_auc_v_nonresonant.pdf")

print(results["auc"])
# Out:
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
# 0.9736277343674312

# %%
selection_string = ((df["process_id"] < 0) | (df["process_id"] == 8)) & (df["train_label"] == 1)
results = utils.calc_roc_and_unc(df.loc[selection_string, "target"], df.loc[selection_string, "bdt_mc_only"], df.loc[selection_string, "weight"])

plot(results["fpr"], results["tpr"], label="AUC = {:0.3f}".format(results["auc"]))
plt.grid()
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Test ROC signal vs GJets")
plt.legend()
plt.savefig("mc_only_auc_v_gjets.pdf")
# Out:
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.
