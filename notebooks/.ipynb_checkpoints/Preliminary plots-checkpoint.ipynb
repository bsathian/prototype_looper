# %%
# %pylab inline
import pandas as pd
import uproot
import awkward as ak
from yahist import Hist1D
from yahist.utils import plot_stack
import mplhep as hep
plt.style.use([hep.style.CMS, hep.style.firamath])
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
t = uproot.open("../output.root")["t"]

# %%
df = t.arrays(library = "pd")

# %%
df.columns
# Out:
# Index(['diphoton_phi', 'MET_phi', 'sublead_pho_pixelSeed', 'sublead_pho_idmva',
#        'sublead_pho_pt', 'diphoton_deltaR', 'sublead_pho_ptmgg',
#        'diphoton_eta', 'lead_pho_pixelSeed', 'weight', 'process_id', 'MET_pt',
#        'lead_pho_ptmgg', 'nJet', 'year', 'lead_pho_pt', 'diphoton_pt',
#        'sublead_pho_phi', 'lead_pho_eta', 'mgg', 'lead_pho_idmva',
#        'sublead_pho_eta', 'lead_pho_phi'],
#       dtype='object')

# %%
process_ids = {}

process_ids["Data"] = 0
process_ids["HH_ggTauTau"] = -1
process_ids["DiPhoton"] = 1
process_ids["GJets"] = 2
process_ids["TTGG"] = 3
process_ids["TTGamma"] = 4
process_ids["TTBar"] = 5
process_ids["VH"] = 6
process_ids["WGamma"] = 7
process_ids["ZGamma"] = 8
process_ids["ttH"] = 9
process_ids["ggH"] = 10
process_ids["VBFH"] = 11

# %%
is_resonant = {}

is_resonant["Data"] = False
is_resonant["DiPhoton"] = False
is_resonant["GJets"] = False
is_resonant["HH_ggTauTau"] = True
is_resonant["TTGG"] = False
is_resonant["TTGamma"] = False
is_resonant["TTBar"] = False
is_resonant["VH"] = True
is_resonant["WGamma"] = False
is_resonant["ZGamma"] = False
is_resonant["ttH"] = True
is_resonant["ggH"] = True
is_resonant["VBFH"] = True

# %% [markdown]
# ### Glorious plots of Glorious BDT distributions

# %%
mgg_binning = "40,100,180" # ROOT convention

mgg_hists = {}
for process, process_id in process_ids.items():
    if is_resonant[process] and "HH_ggTauTau" not in process:
        continue
    toFill = df.loc[df["process_id"] == process_id, "mgg"] # select by process, then select the quantity
    weight = df.loc[df["process_id"] == process_id, "weight"]
    mgg_hists[process] = Hist1D(toFill.values, bins=mgg_binning, label=process, weights=weight)

# plots
# stack non-signals
hist_stack = [hist for process, hist in mgg_hists.items() if process != "HH_ggTauTau" and process != "Data"]
hist_stack = sorted(hist_stack, key=lambda x: x.integral)
fig, ax = plt.subplots()

plot_stack(hist_stack, ax=ax, histtype="stepfilled")
 #mgg_hists["Data"].plot(show_errors=True, color="k")
mgg_hists["HH_ggTauTau"].plot(color="k", histtype="step")
plt.title("Di-Photon Mass Non-resonant backgrounds")
ax.set_yscale("log")
ax.legend(fontsize=10)

# %%
mgg_binning = "40,100,180" # ROOT convention

mgg_hists = {}
for process, process_id in process_ids.items():
    if not is_resonant[process]:
        continue
    toFill = df.loc[df["process_id"] == process_id, "mgg"] # select by process, then select the quantity
    weight = df.loc[df["process_id"] == process_id, "weight"]
    mgg_hists[process] = Hist1D(toFill.values, bins=mgg_binning, label=process, weights=weight)

# plots
# stack non-signals
hist_stack = [hist for process, hist in mgg_hists.items() if process != "HH_ggTauTau" and process != "Data"]
hist_stack = sorted(hist_stack, key=lambda x: x.integral)
fig, ax = plt.subplots()

plot_stack(hist_stack, ax=ax, histtype="stepfilled")
#mgg_hists["Data"].plot(show_errors=True, color="k")
mgg_hists["HH_ggTauTau"].plot(color="k", histtype="step")
plt.title("Di-Photon Mass Resonant backgrounds")
ax.set_yscale("log")
ax.legend(fontsize=10)

# %%
lead_pho_ptmgg_binning = "50,0,10" # ROOT convention

lead_pho_ptmgg_hists = {}
for process, process_id in process_ids.items():
    if not is_resonant[process] or "HH_ggTauTau" in process:
        toFill = df.loc[df["process_id"] == process_id, "lead_pho_ptmgg"] # select by process, then select the quantity
        weight = df.loc[df["process_id"] == process_id, "weight"]
        lead_pho_ptmgg_hists[process] = Hist1D(toFill.values, bins=lead_pho_ptmgg_binning, label=process, weights=weight)

# plots
# stack non-signals
hist_stack = [hist for process, hist in lead_pho_ptmgg_hists.items() if process != "HH_ggTauTau" and process != "Data"]
hist_stack = sorted(hist_stack, key=lambda x: x.integral)
# split by resonant and non-resonant backgrounds
fig, ax = plt.subplots()

plot_stack(hist_stack, ax=ax, histtype="stepfilled")
#lead_pho_ptmgg_hists["Data"].plot(show_errors=True, color="k")
lead_pho_ptmgg_hists["HH_ggTauTau"].plot(color="k", histtype="step")
ax.set_yscale("log")
ax.legend(fontsize=10)
plt.title("Leading photon pt/mgg non-resonant backgrounds")
# Out:
# Text(0.5, 1.0, 'Leading photon pt/mgg non-resonant backgrounds')

# %%
lead_pho_ptmgg_binning = "50,0,10" # ROOT convention

lead_pho_ptmgg_hists = {}
for process, process_id in process_ids.items():
    if is_resonant[process]:
        toFill = df.loc[df["process_id"] == process_id, "lead_pho_ptmgg"] # select by process, then select the quantity
        weight = df.loc[df["process_id"] == process_id, "weight"]
        lead_pho_ptmgg_hists[process] = Hist1D(toFill.values, bins=lead_pho_ptmgg_binning, label=process, weights=weight)

# plots
# stack non-signals
hist_stack = [hist for process, hist in lead_pho_ptmgg_hists.items() if process != "HH_ggTauTau" and process != "Data"]
hist_stack = sorted(hist_stack, key=lambda x: x.integral)
# split by resonant and non-resonant backgrounds
fig, ax = plt.subplots()

plot_stack(hist_stack, ax=ax, histtype="stepfilled")
lead_pho_ptmgg_hists["HH_ggTauTau"].plot(color="k", histtype="step")
ax.set_yscale("log")
ax.legend(fontsize=10)
plt.title("Leading photon pt/mgg resonant backgrounds")
# Out:
# Text(0.5, 1.0, 'Leading photon pt/mgg resonant backgrounds')

# %%
sublead_pho_ptmgg_binning = "30,0,6" # ROOT convention

sublead_pho_ptmgg_hists = {}
for process, process_id in process_ids.items():
    if not is_resonant[process] or "HH_ggTauTau" in process:
        toFill = df.loc[df["process_id"] == process_id, "sublead_pho_ptmgg"] # select by process, then select the quantity
        weight = df.loc[df["process_id"] == process_id, "weight"]
        sublead_pho_ptmgg_hists[process] = Hist1D(toFill.values, bins=sublead_pho_ptmgg_binning, label=process, weights=weight)

# plots
# stack non-signals
hist_stack = [hist for process, hist in sublead_pho_ptmgg_hists.items() if process != "HH_ggTauTau" and process != "Data"]
hist_stack = sorted(hist_stack, key=lambda x: x.integral)
# split by resonant and non-resonant backgrounds
fig, ax = plt.subplots()

plot_stack(hist_stack, ax=ax, histtype="stepfilled")
#sublead_pho_ptmgg_hists["Data"].plot(show_errors=True, color="k")
sublead_pho_ptmgg_hists["HH_ggTauTau"].plot(color="k", histtype="step")
ax.set_yscale("log")
ax.legend(fontsize=10)
plt.title("Sub-leading photon pt/mgg non-resonant backgrounds")
# Out:
# Text(0.5, 1.0, 'Sub-leading photon pt/mgg non-resonant backgrounds')

# %%
sublead_pho_ptmgg_binning = "30,0,6" # ROOT convention

sublead_pho_ptmgg_hists = {}
for process, process_id in process_ids.items():
    if is_resonant[process]:
        toFill = df.loc[df["process_id"] == process_id, "sublead_pho_ptmgg"] # select by process, then select the quantity
        weight = df.loc[df["process_id"] == process_id, "weight"]
        sublead_pho_ptmgg_hists[process] = Hist1D(toFill.values, bins=sublead_pho_ptmgg_binning, label=process, weights=weight)

# plots
# stack non-signals
hist_stack = [hist for process, hist in sublead_pho_ptmgg_hists.items() if process != "HH_ggTauTau" and process != "Data"]
hist_stack = sorted(hist_stack, key=lambda x: x.integral)
# split by resonant and non-resonant backgrounds
fig, ax = plt.subplots()

plot_stack(hist_stack, ax=ax, histtype="stepfilled")
sublead_pho_ptmgg_hists["HH_ggTauTau"].plot(color="k", histtype="step")
ax.set_yscale("log")
ax.legend(fontsize=10)
plt.title("Subleading photon pt/mgg resonant backgrounds")
# Out:
# Text(0.5, 1.0, 'Subleading photon pt/mgg resonant backgrounds')

# %%
lead_pho_pt_binning = "50,0,500" # ROOT convention

lead_pho_pt_hists = {}
for process, process_id in process_ids.items():
    if not is_resonant[process] or "HH_ggTauTau" in process:
        toFill = df.loc[df["process_id"] == process_id, "lead_pho_pt"] # select by process, then select the quantity
        weight = df.loc[df["process_id"] == process_id, "weight"]
        lead_pho_pt_hists[process] = Hist1D(toFill.values, bins=lead_pho_pt_binning, label=process, weights=weight)

# plots
# stack non-signals
hist_stack = [hist for process, hist in lead_pho_pt_hists.items() if process != "HH_ggTauTau" and process != "Data"]
hist_stack = sorted(hist_stack, key=lambda x: x.integral)
# split by resonant and non-resonant backgrounds
fig, ax = plt.subplots()

plot_stack(hist_stack, ax=ax, histtype="stepfilled")
#lead_pho_pt_hists["Data"].plot(show_errors=True, color="k")
lead_pho_pt_hists["HH_ggTauTau"].plot(color="k", histtype="step")
ax.set_yscale("log")
ax.legend(fontsize=10)
plt.title("Leading photon pt non-resonant backgrounds")
# Out:
# Text(0.5, 1.0, 'Leading photon pt non-resonant backgrounds')

# %%
lead_pho_pt_binning = "50,0,500" # ROOT convention

lead_pho_pt_hists = {}
for process, process_id in process_ids.items():
    if is_resonant[process]:
        toFill = df.loc[df["process_id"] == process_id, "lead_pho_pt"] # select by process, then select the quantity
        weight = df.loc[df["process_id"] == process_id, "weight"]
        lead_pho_pt_hists[process] = Hist1D(toFill.values, bins=lead_pho_pt_binning, label=process, weights=weight)

# plots
# stack non-signals
hist_stack = [hist for process, hist in lead_pho_pt_hists.items() if process != "HH_ggTauTau" and process != "Data"]
hist_stack = sorted(hist_stack, key=lambda x: x.integral)
# split by resonant and non-resonant backgrounds
fig, ax = plt.subplots()

plot_stack(hist_stack, ax=ax, histtype="stepfilled")
#ead_pho_pt_hists["Data"].plot(show_errors=True, color="k")
lead_pho_pt_hists["HH_ggTauTau"].plot(color="k", histtype="step")
ax.set_yscale("log")
ax.legend(fontsize=10)
plt.title("Leading photon pt Resonant backgrounds")
# Out:
# Text(0.5, 1.0, 'Leading photon pt Resonant backgrounds')

# %%
sublead_pho_pt_binning = "50,0,500" # ROOT convention

sublead_pho_pt_hists = {}
for process, process_id in process_ids.items():
    if not is_resonant[process] or "HH_ggTauTau" in process:
        toFill = df.loc[df["process_id"] == process_id, "sublead_pho_pt"] # select by process, then select the quantity
        weight = df.loc[df["process_id"] == process_id, "weight"]
        sublead_pho_pt_hists[process] = Hist1D(toFill.values, bins=sublead_pho_pt_binning, label=process, weights=weight)

# plots
# stack non-signals
hist_stack = [hist for process, hist in sublead_pho_pt_hists.items() if process != "HH_ggTauTau" and process != "Data"]
hist_stack = sorted(hist_stack, key=lambda x: x.integral)
# split by resonant and non-resonant backgrounds
fig, ax = plt.subplots()

plot_stack(hist_stack, ax=ax, histtype="stepfilled")
#sublead_pho_pt_hists["Data"].plot(show_errors=True, color="k")
sublead_pho_pt_hists["HH_ggTauTau"].plot(color="k", histtype="step")
ax.set_yscale("log")
ax.legend(fontsize=10)
plt.title("Subleading photon pt non-resonant backgrounds")
# Out:
# Text(0.5, 1.0, 'Subleading photon pt non-resonant backgrounds')

# %%
sublead_pho_pt_binning = "50,0,500" # ROOT convention

sublead_pho_pt_hists = {}
for process, process_id in process_ids.items():
    if is_resonant[process]:
        toFill = df.loc[df["process_id"] == process_id, "sublead_pho_pt"] # select by process, then select the quantity
        weight = df.loc[df["process_id"] == process_id, "weight"]
        sublead_pho_pt_hists[process] = Hist1D(toFill.values, bins=sublead_pho_pt_binning, label=process, weights=weight)

# plots
# stack non-signals
hist_stack = [hist for process, hist in sublead_pho_pt_hists.items() if process != "HH_ggTauTau" and process != "Data"]
hist_stack = sorted(hist_stack, key=lambda x: x.integral)
# split by resonant and non-resonant backgrounds
fig, ax = plt.subplots()

plot_stack(hist_stack, ax=ax, histtype="stepfilled")
#sublead_pho_pt_hists["Data"].plot(show_errors=True, color="k")
sublead_pho_pt_hists["HH_ggTauTau"].plot(color="k", histtype="step")
ax.set_yscale("log")
ax.legend(fontsize=10)
plt.title("Subleading photon pt Resonant backgrounds")
# Out:
# Text(0.5, 1.0, 'Subleading photon pt Resonant backgrounds')

# %%
lead_pho_eta_binning = "100,-2.5,2.5" # ROOT convention

lead_pho_eta_hists = {}
for process, process_id in process_ids.items():
    if not is_resonant[process] or "HH_ggTauTau" in process:
        toFill = df.loc[df["process_id"] == process_id, "lead_pho_eta"] # select by process, then select the quantity
        weight = df.loc[df["process_id"] == process_id, "weight"]
        lead_pho_eta_hists[process] = Hist1D(toFill.values, bins=lead_pho_eta_binning, label=process, weights=weight)

# plots
# stack non-signals
hist_stack = [hist for process, hist in lead_pho_eta_hists.items() if process != "HH_ggTauTau" and process != "Data"]
hist_stack = sorted(hist_stack, key=lambda x: x.integral)
# split by resonant and non-resonant backgrounds
fig, ax = plt.subplots()

plot_stack(hist_stack, ax=ax, histtype="stepfilled")
#lead_pho_eta_hists["Data"].plot(show_errors=True, color="k")
lead_pho_eta_hists["HH_ggTauTau"].plot(color="k", histtype="step")
ax.set_yscale("log")
ax.legend(fontsize=10)
plt.title("Leading Photon eta non-resonant backgrounds")
# Out:
# Text(0.5, 1.0, 'Leading Photon eta non-resonant backgrounds')

# %%
lead_pho_eta_binning = "100,-2.5,2.5" # ROOT convention

lead_pho_eta_hists = {}
for process, process_id in process_ids.items():
    if is_resonant[process]:
        toFill = df.loc[df["process_id"] == process_id, "lead_pho_eta"] # select by process, then select the quantity
        weight = df.loc[df["process_id"] == process_id, "weight"]
        lead_pho_eta_hists[process] = Hist1D(toFill.values, bins=lead_pho_eta_binning, label=process, weights=weight)

# plots
# stack non-signals
hist_stack = [hist for process, hist in lead_pho_eta_hists.items() if process != "HH_ggTauTau" and process != "Data"]
hist_stack = sorted(hist_stack, key=lambda x: x.integral)
# split by resonant and non-resonant backgrounds
fig, ax = plt.subplots()

plot_stack(hist_stack, ax=ax, histtype="stepfilled")
#lead_pho_eta_hists["Data"].plot(show_errors=True, color="k")
lead_pho_eta_hists["HH_ggTauTau"].plot(color="k", histtype="step")
ax.set_yscale("log")
ax.legend(fontsize=10)
plt.title("Leading Photon eta resonant backgrounds")
# Out:
# Text(0.5, 1.0, 'Leading Photon eta resonant backgrounds')

# %%
lead_pho_phi_binning = "100,-3.15,3.15" # ROOT convention

lead_pho_phi_hists = {}
for process, process_id in process_ids.items():
    if not is_resonant[process] or "HH_ggTauTau" in process:
        toFill = df.loc[df["process_id"] == process_id, "lead_pho_phi"] # select by process, then select the quantity
        weight = df.loc[df["process_id"] == process_id, "weight"]
        lead_pho_phi_hists[process] = Hist1D(toFill.values, bins=lead_pho_phi_binning, label=process, weights=weight)

# plots
# stack non-signals
hist_stack = [hist for process, hist in lead_pho_phi_hists.items() if process != "HH_ggTauTau" and process != "Data"]
hist_stack = sorted(hist_stack, key=lambda x: x.integral)
# split by resonant and non-resonant backgrounds
fig, ax = plt.subplots()

plot_stack(hist_stack, ax=ax, histtype="stepfilled")
#lead_pho_phi_hists["Data"].plot(show_errors=True, color="k")
lead_pho_phi_hists["HH_ggTauTau"].plot(color="k", histtype="step")
ax.set_yscale("log")
ax.legend(fontsize=10)
plt.title("Leading Photon phi non-resonant backgrounds")
# Out:
# Text(0.5, 1.0, 'Leading Photon phi non-resonant backgrounds')

# %%
sublead_pho_phi_binning = "100,-3.15,3.15" # ROOT convention

sublead_pho_phi_hists = {}
for process, process_id in process_ids.items():
    if not is_resonant[process] or "HH_ggTauTau" in process:
        toFill = df.loc[df["process_id"] == process_id, "sublead_pho_phi"] # select by process, then select the quantity
        weight = df.loc[df["process_id"] == process_id, "weight"]
        sublead_pho_phi_hists[process] = Hist1D(toFill.values, bins=sublead_pho_phi_binning, label=process, weights=weight)

# plots
# stack non-signals
hist_stack = [hist for process, hist in sublead_pho_phi_hists.items() if process != "HH_ggTauTau" and process != "Data"]
hist_stack = sorted(hist_stack, key=lambda x: x.integral)
# split by resonant and non-resonant backgrounds
fig, ax = plt.subplots()

plot_stack(hist_stack, ax=ax, histtype="stepfilled")
#sublead_pho_phi_hists["Data"].plot(show_errors=True, color="k")
sublead_pho_phi_hists["HH_ggTauTau"].plot(color="k", histtype="step")
ax.set_yscale("log")
ax.legend(fontsize=10)
plt.title("subleading Photon phi non-resonant backgrounds")
# Out:
# Text(0.5, 1.0, 'subleading Photon phi non-resonant backgrounds')

# %%
MET_pt_binning = "50,0,500" # ROOT convention

MET_pt_hists = {}
for process, process_id in process_ids.items():
    if not is_resonant[process] or "HH_ggTauTau" in process:
        toFill = df.loc[df["process_id"] == process_id, "MET_pt"] # select by process, then select the quantity
        weight = df.loc[df["process_id"] == process_id, "weight"]
        MET_pt_hists[process] = Hist1D(toFill.values, bins=MET_pt_binning, label=process, weights=weight)

# plots
# stack non-signals
hist_stack = [hist for process, hist in MET_pt_hists.items() if process != "HH_ggTauTau" and process != "Data"]
hist_stack = sorted(hist_stack, key=lambda x: x.integral)
# split by resonant and non-resonant backgrounds
fig, ax = plt.subplots()

plot_stack(hist_stack, ax=ax, histtype="stepfilled")
#MET_pt_hists["Data"].plot(show_errors=True, color="k")
MET_pt_hists["HH_ggTauTau"].plot(color="k", histtype="step")
ax.set_yscale("log")
ax.legend(fontsize=10)
plt.title("MET pt non-resonant backgrounds")
# Out:
# Text(0.5, 1.0, 'MET pt non-resonant backgrounds')

# %%
MET_pt_binning = "50,0,500" # ROOT convention

MET_pt_hists = {}
for process, process_id in process_ids.items():
    if is_resonant[process]:
        toFill = df.loc[df["process_id"] == process_id, "MET_pt"] # select by process, then select the quantity
        weight = df.loc[df["process_id"] == process_id, "weight"]
        MET_pt_hists[process] = Hist1D(toFill.values, bins=MET_pt_binning, label=process, weights=weight)

# plots
# stack non-signals
hist_stack = [hist for process, hist in MET_pt_hists.items() if process != "HH_ggTauTau" and process != "Data"]
hist_stack = sorted(hist_stack, key=lambda x: x.integral)
# split by resonant and non-resonant backgrounds
fig, ax = plt.subplots()

plot_stack(hist_stack, ax=ax, histtype="stepfilled")
#MET_pt_hists["Data"].plot(show_errors=True, color="k")
MET_pt_hists["HH_ggTauTau"].plot(color="k", histtype="step")
ax.set_yscale("log")
ax.legend(fontsize=10)
plt.title("MET pt Resonant backgrounds")
# Out:
# Text(0.5, 1.0, 'MET pt Resonant backgrounds')

# %%
MET_phi_binning = "50,-3.15,3.15" # ROOT convention

MET_phi_hists = {}
for process, process_id in process_ids.items():
    if not is_resonant[process] or "HH_ggTauTau" in process:
        toFill = df.loc[df["process_id"] == process_id, "MET_phi"] # select by process, then select the quantity
        weight = df.loc[df["process_id"] == process_id, "weight"]
        MET_phi_hists[process] = Hist1D(toFill.values, bins=MET_phi_binning, label=process, weights=weight)

# plots
# stack non-signals
hist_stack = [hist for process, hist in MET_phi_hists.items() if process != "HH_ggTauTau" and process != "Data"]
hist_stack = sorted(hist_stack, key=lambda x: x.integral)
# split by resonant and non-resonant backgrounds
fig, ax = plt.subplots()

plot_stack(hist_stack, ax=ax, histtype="stepfilled")
#MET_phi_hists["Data"].plot(show_errors=True, color="k")
MET_phi_hists["HH_ggTauTau"].plot(color="k", histtype="step")
ax.set_yscale("log")
ax.legend(fontsize=10)
plt.title("MET phi non-resonant backgrounds")
# Out:
# Text(0.5, 1.0, 'MET phi non-resonant backgrounds')

# %%
MET_phi_binning = "50,-3.15,3.15" # ROOT convention

MET_phi_hists = {}
for process, process_id in process_ids.items():
    if is_resonant[process]:
        toFill = df.loc[df["process_id"] == process_id, "MET_phi"] # select by process, then select the quantity
        weight = df.loc[df["process_id"] == process_id, "weight"]
        MET_phi_hists[process] = Hist1D(toFill.values, bins=MET_phi_binning, label=process, weights=weight)

# plots
# stack non-signals
hist_stack = [hist for process, hist in MET_phi_hists.items() if process != "HH_ggTauTau" and process != "Data"]
hist_stack = sorted(hist_stack, key=lambda x: x.integral)
# split by resonant and non-resonant backgrounds
fig, ax = plt.subplots()

plot_stack(hist_stack, ax=ax, histtype="stepfilled")
#MET_phi_hists["Data"].plot(show_errors=True, color="k")
MET_phi_hists["HH_ggTauTau"].plot(color="k", histtype="step")
ax.set_yscale("log")
ax.legend(fontsize=10)
plt.title("MET phi resonant backgrounds")
# Out:
# Text(0.5, 1.0, 'MET phi resonant backgrounds')

# %%
diphoton_deltaR_binning = "50,0,10" # ROOT convention

diphoton_deltaR_hists = {}
for process, process_id in process_ids.items():
    if is_resonant[process]:
        toFill = df.loc[df["process_id"] == process_id, "diphoton_deltaR"] # select by process, then select the quantity
        weight = df.loc[df["process_id"] == process_id, "weight"]
        diphoton_deltaR_hists[process] = Hist1D(toFill.values, bins=diphoton_deltaR_binning, label=process, weights=weight)

# plots
# stack non-signals
hist_stack = [hist for process, hist in diphoton_deltaR_hists.items() if process != "HH_ggTauTau" and process != "Data"]
hist_stack = sorted(hist_stack, key=lambda x: x.integral)
# split by resonant and non-resonant backgrounds
fig, ax = plt.subplots()

plot_stack(hist_stack, ax=ax, histtype="stepfilled")
#diphoton_deltaR_hists["Data"].plot(show_errors=True, color="k")
diphoton_deltaR_hists["HH_ggTauTau"].plot(color="k", histtype="step")
ax.set_yscale("log")
ax.legend(fontsize=10)
plt.title("DiPhoton $\Delta$R resonant backgrounds")
# Out:
# Text(0.5, 1.0, 'DiPhoton $\\Delta$R resonant backgrounds')

# %%
diphoton_deltaR_binning = "50,0,10" # ROOT convention

diphoton_deltaR_hists = {}
for process, process_id in process_ids.items():
    if not is_resonant[process] or "HH_ggTauTau" in process:
        toFill = df.loc[df["process_id"] == process_id, "diphoton_deltaR"] # select by process, then select the quantity
        weight = df.loc[df["process_id"] == process_id, "weight"]
        diphoton_deltaR_hists[process] = Hist1D(toFill.values, bins=diphoton_deltaR_binning, label=process, weights=weight)

# plots
# stack non-signals
hist_stack = [hist for process, hist in diphoton_deltaR_hists.items() if process != "HH_ggTauTau" and process != "Data"]
hist_stack = sorted(hist_stack, key=lambda x: x.integral)
# split by resonant and non-resonant backgrounds
fig, ax = plt.subplots()

plot_stack(hist_stack, ax=ax, histtype="stepfilled")
#diphoton_deltaR_hists["Data"].plot(show_errors=True, color="k")
diphoton_deltaR_hists["HH_ggTauTau"].plot(color="k", histtype="step")
ax.set_yscale("log")
ax.legend(fontsize=10)
plt.title("DiPhoton $\Delta$R non-resonant backgrounds")
# Out:
# Text(0.5, 1.0, 'DiPhoton $\\Delta$R non-resonant backgrounds')
